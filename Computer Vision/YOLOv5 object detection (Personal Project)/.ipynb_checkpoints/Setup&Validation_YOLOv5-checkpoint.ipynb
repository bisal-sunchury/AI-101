# %%
# Clone the YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# Install required packages
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17372, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17372 (delta 42), reused 20 (delta 20), pack-reused 17313 (from 3)
# Receiving objects: 100% (17372/17372), 16.26 MiB | 25.30 MiB/s, done.
# Resolving deltas: 100% (11907/11907), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...

# %%
# Download COCO 2017 val dataset (images + labels)
# This will download to 'coco/' directory
# !bash data/scripts/get_coco.sh
# Out:
# ...
# ######################################################################## 100.0%
# ######################################################################## 100.0%
# ######################################################################## 100.0%

# %%
# Run evaluation on COCO val set
# !python val.py --data coco.yaml --weights yolov5s.pt --task val --img 640 --iou 0.5
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 192MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 21.2MB/s]
# ...

# %%
import os
print(os.path.exists('/content/datasets/coco/images/val2017'))
# Out:
# True

# %%
# !python detect.py --weights yolov5s.pt --source /content/datasets/coco/images/val2017 --conf-thres 0.5 --iou-thres 0.45 --save-conf --save-crop
# Out:
# Streaming output truncated to the last 5000 lines.
# image 3/5000 /content/datasets/coco/images/val2017/000000000632.jpg: 512x640 1 chair, 2 potted plants, 1 bed, 308.2ms
# image 4/5000 /content/datasets/coco/images/val2017/000000000724.jpg: 640x480 1 stop sign, 286.3ms
# image 5/5000 /content/datasets/coco/images/val2017/000000000776.jpg: 640x448 1 teddy bear, 280.6ms
# image 6/5000 /content/datasets/coco/images/val2017/000000000785.jpg: 448x640 1 person, 1 skis, 317.9ms
# image 7/5000 /content/datasets/coco/images/val2017/000000000802.jpg: 640x448 1 oven, 1 refrigerator, 271.5ms
# image 8/5000 /content/datasets/coco/images/val2017/000000000872.jpg: 640x640 1 person, 453.7ms
# image 9/5000 /content/datasets/coco/images/val2017/000000000885.jpg: 448x640 3 persons, 1 tennis racket, 307.9ms
# image 10/5000 /content/datasets/coco/images/val2017/000000001000.jpg: 480x640 11 persons, 2 tennis rackets, 471.8ms
# ...

# %%
# !python val.py --weights yolov5s.pt \
               --data coco.yaml \
               --task val \
               --img 640 \
               --batch-size 16
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# val: Scanning /content/datasets/coco/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 313/313 [37:40<00:00,  7.22s/it]
#                    all       5000      36335      0.669      0.521      0.566      0.371
# Speed: 3.8ms pre-process, 434.1ms inference, 8.0ms NMS per image at shape (16, 3, 640, 640)
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0aed0b93-877f-4baf-841f-f25a1d6cd0fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0aed0b93-877f-4baf-841f-f25a1d6cd0fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.path.exists('/content/yolov5/fur.png'))
# Out:
# True

# %%
# !python detect.py --weights yolov5s.pt --source /content/yolov5/fur.png --conf-thres 0.5 --save-conf --save-crop
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/fur.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=True, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/fur.png: 416x640 3 wine glasss, 5 chairs, 2 potted plants, 502.8ms
# Speed: 10.2ms pre-process, 502.8ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af603da4-8cd8-4ac7-a11d-07fbf1bb7487" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af603da4-8cd8-4ac7-a11d-07fbf1bb7487">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --source /content/yolov5/tra.png --conf-thres 0.5 --save-conf --save-crop
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/tra.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=True, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/tra.png: 416x640 8 cars, 1 truck, 443.9ms
# Speed: 3.0ms pre-process, 443.9ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp11

# %%
# !zip -r mets1.zip /content/yolov5/runs/val/exp2
# Out:
#   adding: content/yolov5/runs/val/exp2/ (stored 0%)
#   adding: content/yolov5/runs/val/exp2/val_batch0_labels.jpg (deflated 9%)
#   adding: content/yolov5/runs/val/exp2/confusion_matrix.png (deflated 16%)
#   adding: content/yolov5/runs/val/exp2/val_batch1_labels.jpg (deflated 7%)
#   adding: content/yolov5/runs/val/exp2/F1_curve.png (deflated 10%)
#   adding: content/yolov5/runs/val/exp2/val_batch0_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/val/exp2/val_batch2_labels.jpg (deflated 7%)
#   adding: content/yolov5/runs/val/exp2/R_curve.png (deflated 10%)
#   adding: content/yolov5/runs/val/exp2/P_curve.png (deflated 8%)
#   adding: content/yolov5/runs/val/exp2/val_batch1_pred.jpg (deflated 7%)
#   adding: content/yolov5/runs/val/exp2/yolov5s_predictions.json (deflated 82%)
#   adding: content/yolov5/runs/val/exp2/PR_curve.png (deflated 7%)
#   adding: content/yolov5/runs/val/exp2/val_batch2_pred.jpg (deflated 7%)
